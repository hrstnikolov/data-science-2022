# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Acquisition

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
frame = pd.DataFrame({
    'col1': [1, 2, 4],
    'col2': [6, 7 , 10],
})

# %%
frame['col1']
# Out:
# 0    1
# 1    2
# 2    4
# Name: col1, dtype: int64

# %% [markdown]
# ```python
# frame[ [put a list here] ]
# ```

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
frame.index.values
# Out:
# array([0, 1, 2], dtype=int64)

# %%
t = 0.001
R = 100
C = 10E-6
Vs = 5
Vs * (1 - np.exp(-t/(R*C)))
# Out:
# 3.1606027941427883
